# %% [markdown]
# # Model Evaluation
#
# Evaluation focuses on metrics suitable for imbalanced classification, prioritizing recall and precision over raw accuracy.

# %%
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score

# %% [markdown]
# Confusion matrices and ROC-AUC scores are used to analyze the trade-offs between false positives and false negatives, which is critical in fraud detection systems.
