# %% [markdown]
# # Model Explainability with SHAP
#
# Explainability is essential in financial ML systems to build trust and satisfy regulatory requirements.

# %%
import shap

# %% [markdown]
# SHAP values provide both global and local interpretability by quantifying each feature's contribution to a model's prediction.
